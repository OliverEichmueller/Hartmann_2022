# %% [markdown]
# # RNA Velocity Plots for lymphoid cells Paper
# ## Import seurat loom and velocyto loom
# * velocyto was run on BAM file produced by CellRanger Count
# * SeuratDisk was used to export Seurat object as loom file

# %% [markdown]
# ### import libraries

# %%
import scanpy as sc
import scvelo as scv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set default figure parameters of scVelo

# %%
scv.set_figure_params()

# %%
sceMerge = scv.read("/Users/Oliver.Eichmueller/velocyto_test/velocyto_objects/filtered_Tcells_211028.h5ad")

# %%
scv.pl.velocity_embedding_stream(sceMerge, basis='umap', color=['integrated_snn_res.0.25'], 
                                 palette=["#332288","#88CCEE","#44AA99","#117733","#999933","#DDCC77","#661100",
                                          "#CC6677","#882255", "#AA4499"], alpha=.2, size=100, 
                                 arrow_size=2, linewidth=1, density = 2.5)

# %%
# this is needed due to a current bug - bugfix is coming soon.
sceMerge.uns['neighbors']['distances'] = sceMerge.obsp['distances']
sceMerge.uns['neighbors']['connectivities'] = sceMerge.obsp['connectivities']

scv.tl.paga(sceMerge, groups='integrated_snn_res.0.25')
df = scv.get_df(sceMerge, 'paga/transitions_confidence', precision=2).T
df.style.background_gradient(cmap='Blues').format('{:.2g}')
# Out:
# running PAGA using priors: ['velocity_pseudotime']
#     finished (0:00:01) --> added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns)
#     'paga/transitions_confidence', velocity transitions (adata.uns)
# <style type="text/css">
# ...

# %%
scv.pl.paga(sceMerge, basis='umap', size=50, alpha=.1,
            min_edge_width=2, node_size_scale=1.5, 
            save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/PAGA_all_025.pdf')
# Out:
# WARNING: Invalid color key. Using grey instead.
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/PAGA_all_025.pdf

# %%
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='rt-1')], basis='umap', 
                                 legend_loc='right margin',fontsize=20,arrow_size=2, linewidth=1, density = 2.5,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_stream.png')
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='rt-2')], basis='umap',  
                                 legend_loc='right margin',fontsize=20,arrow_size=2, linewidth=1, density = 2.5,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_stream.png')
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-1')], basis='umap', 
                                 legend_loc='right margin', fontsize=20,arrow_size=2, linewidth=1, density = 2.5,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12/aC4-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt41_res025_stream.png')
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-2')], basis='umap', 
                                 legend_loc='right margin', fontsize=20,arrow_size=2, linewidth=1, density = 2.5,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12/aC4-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt42_res025_stream.png')
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='untreated-1')], basis='umap',  
                                 legend_loc='right margin',fontsize=20,arrow_size=2, linewidth=1, density = 2.5,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'untreated', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_stream.png')
scv.pl.velocity_embedding_stream(sceMerge, basis='umap',  
                                 legend_loc='right margin',fontsize=20,arrow_size=2, linewidth=1, density = 2.5,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'untreated', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_stream.png')
# Out:
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_stream.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_stream.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt41_res025_stream.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt42_res025_stream.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_stream.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_stream.png
# <AxesSubplot:title={'center':'untreated'}>

# %%
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='rt-1')], basis='umap', 
                                 legend_loc='none',fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_stream_nolab.png')
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='rt-2')], basis='umap',  
                                 legend_loc='none',fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_stream_nolab.png')
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-1')], basis='umap', 
                                 legend_loc='none', fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12/aC4-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt41_res025_stream_nolab.png')
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-2')], basis='umap', 
                                 legend_loc='none', fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12/aC4-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt42_res025_stream_nolab.png')
scv.pl.velocity_embedding_stream(sceMerge[(sceMerge.obs['orig.ident']=='untreated-1')], basis='umap',  
                                 legend_loc='none',fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'untreated', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_stream_nolab.png')
scv.pl.velocity_embedding_stream(sceMerge, basis='umap',  
                                 legend_loc='none',fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'Lymphoid Cells', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_stream_nolab.png')
# Out:
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_stream_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_stream_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt41_res025_stream_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt42_res025_stream_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_stream_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_stream_nolab.png
# <AxesSubplot:title={'center':'Lymphoid Cells'}>

# %%
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rt-1')], basis='umap', 
                                 legend_loc='none',fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_stream_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rt-2')], basis='umap',  
                                 legend_loc='none',fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_stream_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-1')], basis='umap', 
                                 legend_loc='none', fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12/aC4-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt41_res025_stream_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-2')], basis='umap', 
                                 legend_loc='none', fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'C12/aC4-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt42_res025_stream_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='untreated-1')], basis='umap',  
                                 legend_loc='none',fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'untreated', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_stream_nolab.png')
scv.pl.velocity_embedding(sceMerge, basis='umap',  
                                 legend_loc='none',fontsize=20,
                                 color=['integrated_snn_res.0.25'], size =100, title = 'Lymphoid Cells', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_stream_nolab.png')

# %%
scv.pl.velocity_embedding(sceMerge, basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'All Lymphoid Cells', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_single_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='untreated-1')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'untreated-1', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_single_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rt-2')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'C12-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_single_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rt-1')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'C12-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_single_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-2')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'C12/aC4-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rtc42_res025_single_nolab.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-1')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'C12/aC4-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rtc41_res025_single_nolab.png')
# Out:
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_single_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_single_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_single_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_single_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rtc42_res025_single_nolab.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rtc41_res025_single_nolab.png
# <AxesSubplot:title={'center':'C12/aC4-iF'}>

# %%
scv.pl.velocity_embedding(sceMerge, basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0.1, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'All Lymphoid Cells', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_single_nolab_line.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='untreated-1')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0.1, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'untreated-1', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_single_nolab_line.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rt-2')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0.1, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'C12-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_single_nolab_line.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rt-1')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0.1, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'C12-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_single_nolab_line.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-2')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0.1, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'C12/aC4-oF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rtc42_res025_single_nolab_line.png')
scv.pl.velocity_embedding(sceMerge[(sceMerge.obs['orig.ident']=='rtc4-1')], basis='umap', 
                legend_loc='none',fontsize=20,linewidth=0.1, 
                arrow_length = 10, arrow_size=[150,100,150], alpha=0,
                color=['integrated_snn_res.0.25'], title = 'C12/aC4-iF', show=False,
                                save='/Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rtc41_res025_single_nolab_line.png')
# Out:
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/All_res025_single_nolab_line.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/untreated_res025_single_nolab_line.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt2_res025_single_nolab_line.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rt1_res025_single_nolab_line.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rtc42_res025_single_nolab_line.png
# saving figure to file /Users/Oliver.Eichmueller/velocyto_test/plots_TCells/rtc41_res025_single_nolab_line.png
# <AxesSubplot:title={'center':'C12/aC4-iF'}>
